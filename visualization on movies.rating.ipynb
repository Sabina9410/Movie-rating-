# %%
import pandas as pd 
import os                       # os =operating system

# %%
# movies file folder path
movies = pd.read_csv(r"D:\Sabina\Sabina\Movie-Rating.csv")

# %%
# Film = movies name , Genre = types of movies, 
# Rotten tomatos ratings% =represents the percentage of positive reviews for a given film 
# Audience ratings =%
# Budget = budget in millions
# year of release = film released year

# %%
movies
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %% [markdown]
# # Descriptive statistics

# %%
movies.describe()
# Out:
#        Rotten Tomatoes Ratings %  Audience Ratings %  Budget (million $)  \
# count                 559.000000          559.000000          559.000000
# mean                   47.309481           58.744186           50.236136
# std                    26.413091           16.826887           48.731817
# min                     0.000000            0.000000            0.000000
# 25%                    25.000000           47.000000           20.000000
# 50%                    46.000000           58.000000           35.000000
# 75%                    70.000000           72.000000           65.000000
# max                    97.000000           96.000000          300.000000
#
#        Year of release
# count       559.000000
# mean       2009.152057
# std           1.362632
# min        2007.000000
# 25%        2008.000000
# 50%        2009.000000
# 75%        2010.000000
# max        2011.000000

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
# rename columns
movies.columns = ['Film', 'Genre', 'CriticRating', 'AudienceRating', 'BudgetMillions', 'Year']

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'CriticRating', 'AudienceRating', 'BudgetMillions',
#        'Year'],
#       dtype='object')

# %%
# first 5 rows
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.index
# Out:
# RangeIndex(start=0, stop=559, step=1)

# %% [markdown]
# # Check if is there any missing values & its datatype

# %%
movies.isnull()
# Out:
#       Film  Genre  CriticRating  AudienceRating  BudgetMillions   Year
# 0    False  False         False           False           False  False
# 1    False  False         False           False           False  False
# 2    False  False         False           False           False  False
# 3    False  False         False           False           False  False
# 4    False  False         False           False           False  False
# ..     ...    ...           ...             ...             ...    ...
# 554  False  False         False           False           False  False
# 555  False  False         False           False           False  False
# 556  False  False         False           False           False  False
# 557  False  False         False           False           False  False
# 558  False  False         False           False           False  False
#
# [559 rows x 6 columns]

# %% [raw]
#  no any missing value

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %% [markdown]
# # Data visualization

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\Users\SAMEER\anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.25.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
j = sns.jointplot(data =  movies, x ='CriticRating', y='AudienceRating')

# %%
j = sns.jointplot(data =  movies, x ='CriticRating', y='AudienceRating', kind='hex')

# %%
j = sns.jointplot(data =  movies, x ='CriticRating', y='AudienceRating', kind='reg',marker='+')

# %%
#histogram
j1 = sns.distplot(movies.AudienceRating)

# %%
j4 = sns.displot(movies.CriticRating)

# %%
#darkgrid, whitegrid, dark, white, ticks
sns.set_style('darkgrid')

# %%
j2 = sns.distplot(movies.CriticRating)

# %%
sns.set_style('ticks')

# %%
j3 = sns.displot(movies.AudienceRating)

# %%
sns.set_style('whitegrid')

# %%
j5 = sns.displot(movies.Genre)

# %%
sns.set_style('dark')

# %%
j6 = sns.displot(movies.AudienceRating, bins = 2)

# %%
j6 = sns.displot(movies.AudienceRating, bins = 4)

# %%
j6 = sns.histplot(movies.AudienceRating, bins = 222)

# %%
j6 = sns.histplot(movies.AudienceRating, bins = 4)

# %%
sns.set_style('whitegrid')
j6 = sns.displot(movies.AudienceRating, bins = 15)

# %%
p1 = plt.hist(movies.BudgetMillions)

# %%
p1 = plt.hist(movies.BudgetMillions, bins = 20, color='g', align='left')

# %%
p1 = plt.hist(movies.BudgetMillions, bins = 20, color='b',orientation='horizontal')

# %%
p2 = plt.hist(movies[movies.Genre == 'Drama'].BudgetMillions)

# %%
p2 = plt.hist(movies[movies.Genre == 'Action'].BudgetMillions)
plt.legend("blue")
plt.show()

# %%
movies.Genre.unique()
# Out:
# array(['Comedy', 'Adventure', 'Action', 'Horror', 'Drama', 'Romance',
#        'Thriller'], dtype=object)

# %%
p2 = plt.hist(movies[movies.Genre == 'Drama'].BudgetMillions, bins = 20)
p2 = plt.hist(movies[movies.Genre == 'Action'].BudgetMillions, bins = 20)
p2 = plt.hist(movies[movies.Genre == 'Thriller'].BudgetMillions, bins = 20)

# %%
p2 = plt.hist(movies[movies.Genre == 'Action'].BudgetMillions, bins = 20, color='m')
p2 = plt.hist(movies[movies.Genre == 'Thriller'].BudgetMillions, bins = 20, color='r')
p2 = plt.hist(movies[movies.Genre == 'Drama'].BudgetMillions, bins = 20, color='g')

# %%
 # stacked = True ==  multiple data are stacked on top of each other
plt.hist([movies[movies.Genre == 'Action'].BudgetMillions,\
         movies[movies.Genre == 'Thriller'].BudgetMillions,\
         movies[movies.Genre == 'Drama'].BudgetMillions,\
         movies[movies.Genre == 'Comedy'].BudgetMillions],
         bins = 20, stacked = True)
# Out:
# (array([[  7.,  22.,  27.,  16.,   8.,  16.,   9.,   5.,   7.,   6.,  12.,
#            2.,   3.,   8.,   1.,   2.,   1.,   1.,   0.,   1.],
#         [  9.,  33.,  34.,  18.,  12.,  18.,  13.,   6.,   8.,   6.,  13.,
#            2.,   4.,   8.,   1.,   2.,   1.,   1.,   0.,   1.],
#         [ 34.,  73.,  52.,  26.,  18.,  20.,  14.,   6.,   8.,   6.,  14.,
#            2.,   4.,   8.,   1.,   2.,   1.,   1.,   0.,   1.],
#         [ 64., 127.,  88.,  44.,  32.,  34.,  18.,   7.,   8.,   6.,  14.,
#            3.,   4.,   8.,   1.,   2.,   1.,   1.,   0.,   1.]]),
#  array([  0.,  15.,  30.,  45.,  60.,  75.,  90., 105., 120., 135., 150.,
#         165., 180., 195., 210., 225., 240., 255., 270., 285., 300.]),
#  <a list of 4 BarContainer objects>)

# %%
 # stacked = False == multiple data are arranged side by side
plt.hist([movies[movies.Genre == 'Action'].BudgetMillions,\
         movies[movies.Genre == 'Thriller'].BudgetMillions,\
         movies[movies.Genre == 'Drama'].BudgetMillions,\
         movies[movies.Genre == 'Comedy'].BudgetMillions],
         bins = 10, stacked = False)
plt.show()

# %%
# astype=change data type
movies.Genre = movies.Genre.astype('category')

# %%
movies.Genre
# Out:
# 0         Comedy
# 1      Adventure
# 2         Action
# 3      Adventure
# 4         Comedy
#          ...
# 554       Comedy
# 555       Comedy
# 556     Thriller
# 557       Action
# 558       Comedy
# Name: Genre, Length: 559, dtype: category
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
for gen in movies.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
 # predicted values close to the observed  data values == fit regression
# by default fit_reg values is True
v1 = sns.lmplot(data = movies, x='CriticRating', y='AudienceRating')

# %%
v1 = sns.lmplot(data = movies, x='CriticRating', y='AudienceRating',\
               fit_reg=False)

# %%
v1 = sns.lmplot(data = movies, x='AudienceRating', y='CriticRating')

# %%
v2 = sns.lmplot(data = movies, x='CriticRating', y='AudienceRating',\
               fit_reg=False, hue = 'Year')

# %%
v2 = sns.lmplot(data = movies, x='CriticRating', y='AudienceRating',\
               fit_reg=False, hue = 'Genre')

# %%
v2 = sns.lmplot(data = movies, x='CriticRating', y='AudienceRating',\
               fit_reg=False, hue = 'Genre', col='Year')

# %%
#aspect gives the width of each facet in inches.    
v2 = sns.lmplot(data = movies, x='CriticRating', y='AudienceRating',\
               fit_reg=False, hue = 'Genre', size=10, aspect=2)

# %%
v2 = sns.lmplot(data = movies, x='CriticRating', y='AudienceRating',\
               fit_reg=False, hue = 'Genre', size=5, aspect=1)

# %%
sns.set_style('darkgrid')
v2 = sns.lmplot(data = movies, x='CriticRating', y='AudienceRating',\
               fit_reg=False, hue = 'Genre', size=10, aspect=1)

# %%
sns.countplot(movies.CriticRating)
# Out:
# <AxesSubplot:xlabel='CriticRating', ylabel='count'>

# %%
sns.countplot(movies.AudienceRating)
# Out:
# <AxesSubplot:xlabel='AudienceRating', ylabel='count'>

# %%
movies.boxplot(by='Year',figsize=(12,6))
# Out:
# array([[<AxesSubplot:title={'center':'AudienceRating'}, xlabel='[Year]'>,
#         <AxesSubplot:title={'center':'BudgetMillions'}, xlabel='[Year]'>],
#        [<AxesSubplot:title={'center':'CriticRating'}, xlabel='[Year]'>,
#         <AxesSubplot:>]], dtype=object)

# %%
movies.boxplot(by='Genre',figsize=(10,6), rot=1)
# Out:
# array([[<AxesSubplot:title={'center':'AudienceRating'}, xlabel='[Genre]'>,
#         <AxesSubplot:title={'center':'BudgetMillions'}, xlabel='[Genre]'>],
#        [<AxesSubplot:title={'center':'CriticRating'}, xlabel='[Genre]'>,
#         <AxesSubplot:title={'center':'Year'}, xlabel='[Genre]'>]],
#       dtype=object)

# %%
# kdeplot == kernel density estimate plot

# %%
sns.set_style('ticks')

# %%
k1 = sns.kdeplot(movies.AudienceRating)

# %%
sns.set_style='grid'
k2 = sns.kdeplot(movies.AudienceRating,movies.CriticRating)

# %%
 # shade lowesst= False == area below the lowest contour will be transparent
k2 = sns.kdeplot(movies.AudienceRating,movies.CriticRating, shade=True, shade_lowest=False)

# %%
k2 = sns.kdeplot(movies.AudienceRating,movies.CriticRating, shade=True, shade_lowest=True)

# %%
# levels == Number of contour levels
k2 = sns.kdeplot(movies.AudienceRating,movies.CriticRating,shade_lowest=False,cmap='Greens',levels=14, thresh=.5)

# %%
k2 = sns.kdeplot(movies.AudienceRating,movies.CriticRating,shade_lowest=False,cmap='Paired')

# %%
k2 = sns.kdeplot(movies.AudienceRating,movies.BudgetMillions,shade_lowest=False,cmap='winter')

# %%
k2 = sns.kdeplot(movies.AudienceRating,movies.BudgetMillions,shade_lowest=False,cmap='winter_r')

# %%
k2 = sns.kdeplot(movies.BudgetMillions,movies.CriticRating,thresh=.2)

# %%
k2 = sns.kdeplot(movies.BudgetMillions,movies.CriticRating,thresh=.1)

# %%
#subplots
f, ax = plt.subplots(1,2, figsize =(12,6))

# %%
sns.set_style = 'darkgrid'

# %%
f, ax = plt.subplots(3,3, figsize =(6,2))

# %%
f, axes = plt.subplots(1,2, figsize=(8,4))
k1 = sns.kdeplot(movies.BudgetMillions,movies.AudienceRating,ax=axes[0])
k2 = sns.kdeplot(movies.BudgetMillions,movies.CriticRating,ax=axes[1])

# %%
f, axes = plt.subplots(1,2, figsize=(8,4))
k1 = sns.kdeplot(movies.BudgetMillions,movies.AudienceRating,ax=axes[1],levels=4)
k2 = sns.kdeplot(movies.BudgetMillions,movies.CriticRating,ax=axes[1],levels=4)

# %%
axes
# Out:
# array([<AxesSubplot:>,
#        <AxesSubplot:xlabel='BudgetMillions', ylabel='AudienceRating'>],
#       dtype=object)

# %%
# box plot
b = sns.boxplot(data=movies, x ='Genre', y = 'CriticRating',saturation=10)

# %%
b = sns.boxplot(data=movies, x ='Genre', y = 'CriticRating', saturation=0.2)

# %%
b = sns.boxplot(data=movies, x ='Genre', y = 'CriticRating',saturation=10, linewidth=4)

# %%
b2=sns.boxenplot(data=movies.AudienceRating)

# %%
b = sns.boxplot(data=movies[movies.Genre=='Drama'], x='Year', y='CriticRating')

# %%
b = sns.boxplot(data=movies[movies.Genre=='Action'], x='Year', y='AudienceRating')

# %%
#violin plot
v = sns.violinplot(data=movies, x='Genre', y='CriticRating',linewidth=1,saturation=4)

# %%
v = sns.violinplot(data=movies, x='Genre', y='CriticRating',linewidth=1,cut=10)

# %%
#facetgrid
f = sns.FacetGrid(data=movies, row='Genre', col='Year', hue='Genre')

# %%
plt.scatter(movies.CriticRating,movies.AudienceRating)
plt.show()

# %%
f = sns.FacetGrid(data=movies, row='Genre', col='Year', hue='Genre')
f = f.map(plt.scatter, 'CriticRating', 'AudienceRating')

# %%
f = sns.FacetGrid(data=movies, row='Genre', col='Year', hue='Genre')
f = f.map(plt.hist,'BudgetMillions')

# %%
f = sns.FacetGrid(data=movies, row='Genre', col='Year', hue='Genre')
kws = dict(s=60, linewidth=1.5, edgecolor='black')
f = f.map(plt.scatter, 'CriticRating', 'AudienceRating', **kws)

# %%
  # DISTRIBUTION PLOT == *distplot =(histogram f selected continuous variable) (univariate ),
                       *jointplot =(combination f d distplot f two variables) (bivariate),
                       *pairplot =(takes all attributes of data and plot pairwise scatter plot
                              for 2 diff. variables and same variables for histogram),
                      *rugplot =(dash mark)
 # CATEGORICAL PLOT == barplot(bivariate),
                    countplot(counts d no. of occurence f categorical variables),
                  boxplot(continous variable)
                , violoinplot
 grids=FAcetgrids
# Histogram = most common =for visualization distribution
   # Scatter plot = it showing distribution in large data sets, shows d relationship between two numerical variables
